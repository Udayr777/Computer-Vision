# %%
# !nvidia-smi
# Out:
# Tue Jan 16 04:10:44 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   48C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 699.7/699.7 kB 6.0 MB/s eta 0:00:00
# ...

# %%
# importing libraries
from ultralytics import YOLO

# %%
# !yolo task=detect model=predict model=yolov8l.pt conf=0.25 source="https://ultralytics.com/images/bus.jpg"
# Out:
# WARNING ⚠️ 'mode' is missing. Valid modes are ('train', 'val', 'predict', 'export', 'track', 'benchmark'). Using default 'mode=train'.
# ...
# 100% 83.7M/83.7M [00:00<00:00, 237MB/s]
# WARNING ⚠️ 'data' is missing. Using default 'data=coco8.yaml'.
# Ultralytics YOLOv8.1.2 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=train model=yolov8l.pt data= ../content/drive/MyDrive/Kaggle_Dataset/ConstructionSiteSafety/data.yaml epochs=50  imgsz=640 verbose=True
# Out:
# Ultralytics YOLOv8.1.2 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
